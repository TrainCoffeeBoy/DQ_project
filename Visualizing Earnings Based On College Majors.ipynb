# %% [markdown]
# # Visualizing Earnings Based On College Majors
#
# Do students in more popular majors make more money?
#  - Not really
#
# Do students that majored in subjects that were majority female make more money?
#  - No. It is likely to have less money.
#
# Is there any link between the number of full-time employees and median salary?
#  - Fewer full-time employees have more money.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read dataset
recent_grads = pd.read_csv("recent-grads.csv")

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
# the number of rows in raw data
raw_data_count = recent_grads.shape

# %%
# find the row with NaN data
recent_grads[recent_grads['Total'].isnull() == True]
# Out:
#     Rank  Major_code         Major  Total  Men  Women  \
# 21    22        1104  FOOD SCIENCE    NaN  NaN    NaN
#
#                      Major_category  ShareWomen  Sample_size  Employed  ...  \
# 21  Agriculture & Natural Resources         NaN           36      3149  ...
#
#     Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 21       1121                  1735         338           0.096931   53000
#
#     P25th  P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 21  32000  70000          1183              1274            485
#
# [1 rows x 21 columns]

# %%
# drop the row with NaN data
recent_grads = recent_grads.dropna()

# %%
# count the number of cleaned data set
cleaned_data_count = recent_grads.shape

# %%
print(cleaned_data_count, raw_data_count)
# Out:
# (172, 21) (173, 21)

# %%
# generate scatter plots
# Sample size and Median
recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Sample_size vs Median')

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Sample_size vs Unemployment_rate')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', title='Full_time vs Median')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='ShareWomen vs Unemployment_rate')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter', title='Men vs Median')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter', title='Women vs Median')

# %% [markdown]
# Do students in more popular majors make more money?
#  - Not really
#
# Do students that majored in subjects that were majority female make more money?
#  - No. It is likely to have less money.
#
# Is there any link between the number of full-time employees and median salary?
#  - Fewer full-time employees have more money.

# %%
# Genearte histrrams of...
recent_grads['Sample_size'].hist(bins=25, range=(0,200))
plt.title('Sample_Size')
# Out:
# Text(0.5, 1.0, 'Sample_Size')

# %%
recent_grads['Median'].hist(bins=25,range=(20000,60000))
plt.title('Median')
# Out:
# Text(0.5, 1.0, 'Median')

# %%
recent_grads['Employed'].hist(bins=25,range=(0,50000))
plt.title('Employed')
# Out:
# Text(0.5, 1.0, 'Employed')

# %%
recent_grads['Full_time'].hist(bins=25,range=(0,50000))
plt.title('Full_time')
# Out:
# Text(0.5, 1.0, 'Full_time')

# %%
recent_grads['ShareWomen'].hist(range=(0,0.5))
plt.title('ShareWoman')
# Out:
# Text(0.5, 1.0, 'ShareWoman')

# %%
recent_grads[recent_grads['ShareWomen']<0.5].shape[0] / recent_grads.shape[0] * 100
# Out:
# 44.18604651162791

# %%
recent_grads['Men'].hist(bins=25,range=(0,30000))
plt.title('Men')
# Out:
# Text(0.5, 1.0, 'Men')

# %%
recent_grads['Women'].hist()
plt.title('Women')
# Out:
# Text(0.5, 1.0, 'Women')

# %% [markdown]
# Q. What percent of majors are predominantly male? Predominantly female?
# A.  44% are predominantly male and 56% of predominatly female.
#
# Q. What's the most common median salary range?
# A. Around 35,000.

# %%
pd.plotting.scatter_matrix(recent_grads[['Sample_size','Median']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x120c7ad50>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x121510a90>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(recent_grads[['Full_time','ShareWomen','Median']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1219415d0>,
# ...
#       dtype=object)

# %% [markdown]
# Do students in more popular majors make more money?
# No
#
# Do students that majored in subjects that were majority female make more money?
# No. There is negative corelation.
#
# Is there any link between the number of full-time employees and median salary?
# Increase fo full-time employees increases the bottom of median salary

# %%
recent_grads[:10]['ShareWomen'].plot(kind='bar', title='First 10 rows of ShareWomen')

# %%
recent_grads[-10:]['ShareWomen'].plot(kind='bar', title='Last 10 rows of ShareWomen')

# %%
recent_grads[:10]['Unemployment_rate'].plot(kind='bar', title='First 10 rows of Unemployment_rate')

# %%
recent_grads[-10:]['Unemployment_rate'].plot(kind='bar', title='Last 10 rows of Unemployment_rate')

# %% [markdown]
# Use a grouped bar plot to compare the number of men with the number of women in each category of majors.
#
# Use a box plot to explore the distributions of median salaries and unemployment rate.
#
# Use a hexagonal bin plot to visualize the columns that had dense scatter plots from earlier in the project.

# %%
recent_grads.plot.bar(x='Major', y=['Men','Women'],figsize=(10,10))

# %%
recent_grads.boxplot(column=['Median','Unemployment_rate'])

# %%
recent_grads['Median'].plot(kind='box')

# %%
recent_grads['Unemployment_rate'].plot(kind='box')

# %%
recent_grads.plot.hexbin(y='Median', x='Sample_size',xlim=[0,1000],ylim=[20000,50000],figsize=(10,10))
